# %%
import pandas as pd

# %% [markdown]
# import the pandas libraries and name it as pd. i can refer to the library now as pd instead of writing pandas

# %%
df = pd.read_csv('results.csv')

# %% [markdown]
# import the csv data named results.csv and name it df. pd means the panda library and df its the name of the dataframe i'll be using. if the csv use something different from commas (,), use the command delimiter df = pd.read_csv('results.csv, delimiter = ";"'). it it use semicollons (;) or something else

# %%
df.head(10)
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType       Value  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party  £20,000.00
# 1  C0364233                 Liberal Democrats     Political Party   £1,800.00
# 2  C0364187                 Liberal Democrats     Political Party   £3,000.00
# 3  C0364207                 Liberal Democrats     Political Party   £1,560.00
# 4  C0364113                 Liberal Democrats     Political Party   £7,750.00
# 5  C0364156                 Liberal Democrats     Political Party   £1,800.00
# 6  C0364219                 Liberal Democrats     Political Party   £1,838.00
# 7  C0364238                 Liberal Democrats     Political Party   £1,779.00
# 8  C0364264                 Liberal Democrats     Political Party   £2,400.00
# 9  C0364101                 Liberal Democrats     Political Party   £1,560.00
#
#   AcceptedDate                AccountingUnitName                   DonorName  \
# ...

# %% [markdown]
# df is the name of the data frame head(10) is to show the first 10 rows of my results.csv file

# %%
df.tail(10)
# Out:
#          ECRef              RegulatedEntityName RegulatedEntityType  \
# 290  NC0364001     UK Independence Party (UKIP)     Political Party
# 291   C0376428  Conservative and Unionist Party     Political Party
# 292   C0363992     UK Independence Party (UKIP)     Political Party
# 293   C0364019     UK Independence Party (UKIP)     Political Party
# 294   C0363993     UK Independence Party (UKIP)     Political Party
# 295   C0363988     UK Independence Party (UKIP)     Political Party
# 296   C0364018     UK Independence Party (UKIP)     Political Party
# 297   C0364007     UK Independence Party (UKIP)     Political Party
# 298   C0363987     UK Independence Party (UKIP)     Political Party
# 299   C0393892                     Labour Party     Political Party
#
#          Value AcceptedDate        AccountingUnitName  \
# 290    £650.00   31/03/2017   Harwich and North Essex
# 291  £2,500.00   27/03/2017                    Havant
# ...

# %% [markdown]
# this command show the last 10 rows of the dataframe

# %%
df.sample()
# Out:
#          ECRef              RegulatedEntityName RegulatedEntityType  \
# 231  NC0376442  Conservative and Unionist Party     Political Party
#
#          Value AcceptedDate AccountingUnitName          DonorName  \
# 231  £3,900.00   25/10/2017      Central Party  Mr James R Lupton
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  ...  \
# 231                          False           True  Individual  ...
#
#      IsReportedPrePoll  ReportingPeriodName  IsBequest IsAggregation  \
# 231                NaN              Q4 2017      False          True
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 231                52               NaN    34266             NaN
#
#       RegisterName  IsIrishSource
# 231  Great Britain          False
#
# [1 rows x 29 columns]

# %% [markdown]
# this command show one random row of sample

# %%
df.sample(10)
# Out:
#         ECRef              RegulatedEntityName RegulatedEntityType  \
# 24   C0364256                Liberal Democrats     Political Party
# 59   C0364248                Liberal Democrats     Political Party
# 61   C0364242                Liberal Democrats     Political Party
# 221  C0376318  Conservative and Unionist Party     Political Party
# 279  C0376410  Conservative and Unionist Party     Political Party
# 183  C0364320           British National Party     Political Party
# 92   C0364246                Liberal Democrats     Political Party
# 184  C0393885                     Labour Party     Political Party
# 124  C0376332  Conservative and Unionist Party     Political Party
# 89   C0364241                Liberal Democrats     Political Party
#
#           Value AcceptedDate    AccountingUnitName             DonorName  \
# 24    £1,743.93   31/12/2017  Cardiff and the Vale        Mr Ashley Wood
# 59    £2,001.66   31/12/2017            Winchester    Mr Dominic Hiscock
# ...

# %% [markdown]
# this command shows me 10 random rows

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# ...

# %% [markdown]
# this command shows the data type in every collom. object or string is a text, float is a decimal number, integer is a number with no comma, bool is a boolean, yes or no, true or false

# %%
df.shape
# Out:
# (300, 29)

# %% [markdown]
# this command shows whats in the cvs. its have 300 rolls and 29 collums

# %%
df.describe()
# Out:
#        RegulatedDoneeType  CompanyRegistrationNumber  Postcode  \
# count                 0.0                        0.0       0.0
# mean                  NaN                        NaN       NaN
# std                   NaN                        NaN       NaN
# min                   NaN                        NaN       NaN
# 25%                   NaN                        NaN       NaN
# 50%                   NaN                        NaN       NaN
# 75%                   NaN                        NaN       NaN
# max                   NaN                        NaN       NaN
#
#        PurposeOfVisit  DonationAction  IsReportedPrePoll  RegulatedEntityId  \
# count             0.0             0.0                0.0         300.000000
# mean              NaN             NaN                NaN         138.116667
# std               NaN             NaN                NaN         596.037318
# min               NaN             NaN                NaN          52.000000
# ...

# %% [markdown]
# this command shows a statical summary of the data. NaN mean Not a Number.

# %%
df.sample()
# Out:
#        ECRef RegulatedEntityName RegulatedEntityType      Value AcceptedDate  \
# 78  C0364108   Liberal Democrats     Political Party  £1,676.78   31/12/2017
#
#             AccountingUnitName       DonorName  AccountingUnitsAsCentralParty  \
# 78  Mid Dorset and North Poole  Mr David Brown                          False
#
#     IsSponsorship DonorStatus  ...  IsReportedPrePoll  ReportingPeriodName  \
# 78          False  Individual  ...                NaN              Q4 2017
#
#     IsBequest IsAggregation RegulatedEntityId  AccountingUnitId  DonorId  \
# 78      False          True                90            2116.0    83330
#
#    CampaigningName   RegisterName  IsIrishSource
# 78             NaN  Great Britain          False
#
# [1 rows x 29 columns]

# %%
df['ValueClean'] = df['Value'].str.replace('£',"")

# %% [markdown]
# i created a new collum in my df dataframe namae ValueClean, based in the old collum Value, and replaced the £ in every row for nothing

# %%
df.head()
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType       Value  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party  £20,000.00
# 1  C0364233                 Liberal Democrats     Political Party   £1,800.00
# 2  C0364187                 Liberal Democrats     Political Party   £3,000.00
# 3  C0364207                 Liberal Democrats     Political Party   £1,560.00
# 4  C0364113                 Liberal Democrats     Political Party   £7,750.00
#
#   AcceptedDate        AccountingUnitName              DonorName  \
# 0   19/12/2018             Central Party  Mr Alun Ffred Jones
# 1   31/12/2017           Greater Reading       Ms Kirsten Bayes
# 2   31/12/2017     South Gloucestershire         Mr Steve  Webb
# 3   31/12/2017  Westmorland and Lonsdale          Mr Tim Farron
# 4   31/12/2017             Central Party    Mr Duncan Greenland
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  ...  \
# ...

# %%
df['ValueClean'] = df['ValueClean'].str.replace(',',"")

# %% [markdown]
# i created a new collum in my df dataframe named ValueClean, based in the old collum ValueClean, and replaced the , in every row for nothing and the code overwrited the ValueClean

# %%
df.sample()
# Out:
#        ECRef RegulatedEntityName RegulatedEntityType      Value AcceptedDate  \
# 44  C0364236   Liberal Democrats     Political Party  £1,557.25   31/12/2017
#
#    AccountingUnitName        DonorName  AccountingUnitsAsCentralParty  \
# 44      The Cotswolds  Cllr Joe Harris                          False
#
#     IsSponsorship DonorStatus  ...  ReportingPeriodName  IsBequest  \
# 44          False  Individual  ...              Q4 2017      False
#
#     IsAggregation RegulatedEntityId AccountingUnitId  DonorId  \
# 44           True                90           1900.0    75240
#
#     CampaigningName   RegisterName IsIrishSource  ValueClean
# 44              NaN  Great Britain         False     1557.25
#
# [1 rows x 30 columns]

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# ...

# %%
df['ValueClean'] = pd.to_numeric(df['ValueClean'])

# %% [markdown]
# this command created a new collum called ValueClean and setted the collum to numeric type based on the old ValueClean and overwrited it

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# Value                             object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# ...

# %%
df = df.drop('Value', 1)

# %% [markdown]
# i created a new dataframe called df based ond the old df, but (dropped) the collum Value. i said to python the its a collum by writing 1, if it was a row, i should have used 0

# %%
df.sample()
# Out:
#       ECRef RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 7  C0364238   Liberal Democrats     Political Party   31/12/2017
#
#   AccountingUnitName         DonorName  AccountingUnitsAsCentralParty  \
# 7         Gloucester  Mr Jeremy Hilton                          False
#
#    IsSponsorship DonorStatus  RegulatedDoneeType  ...  ReportingPeriodName  \
# 7          False  Individual                 NaN  ...              Q4 2017
#
#    IsBequest IsAggregation RegulatedEntityId  AccountingUnitId  DonorId  \
# 7      False          True                90            1991.0    83347
#
#   CampaigningName   RegisterName  IsIrishSource ValueClean
# 7             NaN  Great Britain          False     1779.0
#
# [1 rows x 29 columns]

# %%
df = df.rename(columns={'ValueClean':'Value'})
df.sample()
# Out:
#         ECRef           RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 163  C0364006  UK Independence Party (UKIP)     Political Party   04/12/2017
#
#     AccountingUnitName            DonorName  AccountingUnitsAsCentralParty  \
# 163      Central Party  Mrs Catherine Pirie                          False
#
#      IsSponsorship DonorStatus  RegulatedDoneeType  ...  ReportingPeriodName  \
# 163          False  Individual                 NaN  ...              Q4 2017
#
#      IsBequest IsAggregation RegulatedEntityId  AccountingUnitId  DonorId  \
# 163      False          True                85               NaN    74685
#
#     CampaigningName   RegisterName  IsIrishSource   Value
# 163             NaN  Great Britain          False  2000.0
#
# [1 rows x 29 columns]

# %% [markdown]
# a created a new dataframe called df based on the old df but renamed de column ValueClean to Value and overwrited it and automatically showed a sample

# %%
df.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value'],
#       dtype='object')

# %% [markdown]
# i used this command to see if it has spaces or traillins spaces in the colunms anmes

# %%
df['DonorName'].unique()
# Out:
# array(['Mr Alun Ffred Jones  ', 'Ms Kirsten Bayes', 'Mr Steve  Webb',
#        'Mr Tim Farron', 'Mr Duncan Greenland', 'Mr Michael Lees',
#        'Ms Jane Mactaggart', 'Mr Jeremy Hilton',
#        'Baroness Kathryn Parminter', 'Lady Catherine Bakewell',
#        'Mr Martin Elengorn', 'Cllr Ian Shires', 'Ms Liz  Morris',
#        'Dr Alun  Griffiths', 'Mr Dave  Hodgson', 'Mr David Goodwin',
#        'Mrs Elizabeth Barraclough', 'Baroness Shirley Williams',
#        'Lord Tim Clement-Jones', 'Mr Mark  Burch', 'Mr Arthur Hookway',
#        'Mr Brett Hammond', 'Mr Ashley Wood', 'Mrs Rowena Hay',
#        'Ms Lynne Featherstone', 'Ms Inga Lockington', 'Mr Peter Rothery',
#        'Mr Richard Keatinge', 'Mr Cliff Woodcraft', 'Mr Derek Eastman',
#        'Ms Gail  Engert', 'Mr Pathumal Ali', 'Mrs Klara Sudbury',
#        'Mr James Macpherson', 'Mr David Tutt', 'Mr Colin  Stears',
#        'Ms Mary Wane', 'Mr Alistair  Barr', 'Miss Jocelyn Clark',
# ...

# %% [markdown]
# this command is to show the contents of the unique column DonorName so i can see if its have extra spaces in the names

# %%
df['DonorName'] = df['DonorName'].map(str.strip)

# %% [markdown]
# in the DonorName column i removed all the spaces before and after the names with the command .map(str.strip and overwrited it

# %%
df['DonorName'].unique()
# Out:
# array(['Mr Alun Ffred Jones', 'Ms Kirsten Bayes', 'Mr Steve  Webb',
#        'Mr Tim Farron', 'Mr Duncan Greenland', 'Mr Michael Lees',
#        'Ms Jane Mactaggart', 'Mr Jeremy Hilton',
#        'Baroness Kathryn Parminter', 'Lady Catherine Bakewell',
#        'Mr Martin Elengorn', 'Cllr Ian Shires', 'Ms Liz  Morris',
#        'Dr Alun  Griffiths', 'Mr Dave  Hodgson', 'Mr David Goodwin',
#        'Mrs Elizabeth Barraclough', 'Baroness Shirley Williams',
#        'Lord Tim Clement-Jones', 'Mr Mark  Burch', 'Mr Arthur Hookway',
#        'Mr Brett Hammond', 'Mr Ashley Wood', 'Mrs Rowena Hay',
#        'Ms Lynne Featherstone', 'Ms Inga Lockington', 'Mr Peter Rothery',
#        'Mr Richard Keatinge', 'Mr Cliff Woodcraft', 'Mr Derek Eastman',
#        'Ms Gail  Engert', 'Mr Pathumal Ali', 'Mrs Klara Sudbury',
#        'Mr James Macpherson', 'Mr David Tutt', 'Mr Colin  Stears',
#        'Ms Mary Wane', 'Mr Alistair  Barr', 'Miss Jocelyn Clark',
# ...

# %%
import datetime

# %% [markdown]
# i imported the library datetime from python

# %%
df.head(5)
# Out:
#       ECRef               RegulatedEntityName RegulatedEntityType  \
# 0  C0363977  Plaid Cymru - The Party of Wales     Political Party
# 1  C0364233                 Liberal Democrats     Political Party
# 2  C0364187                 Liberal Democrats     Political Party
# 3  C0364207                 Liberal Democrats     Political Party
# 4  C0364113                 Liberal Democrats     Political Party
#
#   AcceptedDate        AccountingUnitName            DonorName  \
# 0   19/12/2018             Central Party  Mr Alun Ffred Jones
# 1   31/12/2017           Greater Reading     Ms Kirsten Bayes
# 2   31/12/2017     South Gloucestershire       Mr Steve  Webb
# 3   31/12/2017  Westmorland and Lonsdale        Mr Tim Farron
# 4   31/12/2017             Central Party  Mr Duncan Greenland
#
#    AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 0                          False          False  Individual
# 1                          False          False  Individual
# ...

# %%
df.dtypes
# Out:
# ECRef                             object
# RegulatedEntityName               object
# RegulatedEntityType               object
# AcceptedDate                      object
# AccountingUnitName                object
# DonorName                         object
# AccountingUnitsAsCentralParty       bool
# IsSponsorship                       bool
# DonorStatus                       object
# RegulatedDoneeType               float64
# CompanyRegistrationNumber        float64
# Postcode                         float64
# DonationType                      object
# NatureOfDonation                  object
# PurposeOfVisit                   float64
# DonationAction                   float64
# ReceivedDate                      object
# ReportedDate                      object
# IsReportedPrePoll                float64
# ReportingPeriodName               object
# IsBequest                           bool
# IsAggregation                       bool
# RegulatedEntityId                  int64
# ...

# %%
df['AcceptedDate'] = pd.to_datetime(df['AcceptedDate'], format="%d/%m/%Y")

# %% [markdown]
# take the column AcceptedDate and change it to date and time format, named it AcceptedDate and overwrited. i choose the format 10/10/1995 using % as a number 0 for day and month and Y capital to use four numbers. lower y is two numbers

# %%
df.dtypes
# Out:
# ECRef                                    object
# RegulatedEntityName                      object
# RegulatedEntityType                      object
# AcceptedDate                     datetime64[ns]
# AccountingUnitName                       object
# DonorName                                object
# AccountingUnitsAsCentralParty              bool
# IsSponsorship                              bool
# DonorStatus                              object
# RegulatedDoneeType                      float64
# CompanyRegistrationNumber               float64
# Postcode                                float64
# DonationType                             object
# NatureOfDonation                         object
# PurposeOfVisit                          float64
# DonationAction                          float64
# ReceivedDate                             object
# ReportedDate                             object
# IsReportedPrePoll                       float64
# ReportingPeriodName                      object
# ...

# %%
df['ReceivedDate'] = pd.to_datetime(df['ReceivedDate'], format="%d/%m/%Y")

# %%
df['ReportedDate'] = pd.to_datetime(df['ReportedDate'], format="%d/%m/%Y")

# %%
df.dtypes
# Out:
# ECRef                                    object
# RegulatedEntityName                      object
# RegulatedEntityType                      object
# AcceptedDate                     datetime64[ns]
# AccountingUnitName                       object
# DonorName                                object
# AccountingUnitsAsCentralParty              bool
# IsSponsorship                              bool
# DonorStatus                              object
# RegulatedDoneeType                      float64
# CompanyRegistrationNumber               float64
# Postcode                                float64
# DonationType                             object
# NatureOfDonation                         object
# PurposeOfVisit                          float64
# DonationAction                          float64
# ReceivedDate                     datetime64[ns]
# ReportedDate                     datetime64[ns]
# IsReportedPrePoll                       float64
# ReportingPeriodName                      object
# ...

# %%
df.sample()
# Out:
#         ECRef RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 269  C0364133   Liberal Democrats     Political Party   2017-06-30
#
#          AccountingUnitName           DonorName  \
# 269  Liberal Democrat Women  Ms Jane Mactaggart
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 269                          False          False  Individual
#
#      RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 269                 NaN  ...              Q4 2017      False         False
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 269                90            2399.0    55988             NaN
#
#       RegisterName  IsIrishSource    Value
# 269  Great Britain          False  23000.0
#
# [1 rows x 29 columns]

# %%
df['AcceptedDate'] = pd.to_datetime(df['AcceptedDate'], format="%d-%m-%Y")

# %%
df.sample()
# Out:
#         ECRef              RegulatedEntityName RegulatedEntityType  \
# 291  C0376428  Conservative and Unionist Party     Political Party
#
#     AcceptedDate AccountingUnitName       DonorName  \
# 291   2017-03-27             Havant  Mr Jeremy Hand
#
#      AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  \
# 291                          False          False  Individual
#
#      RegulatedDoneeType  ...  ReportingPeriodName  IsBequest IsAggregation  \
# 291                 NaN  ...              Q4 2017      False         False
#
#     RegulatedEntityId  AccountingUnitId  DonorId CampaigningName  \
# 291                52            1253.0    83880             NaN
#
#       RegisterName  IsIrishSource   Value
# 291  Great Britain          False  2500.0
#
# [1 rows x 29 columns]

# %%
df['Year'] = pd.DatetimeIndex(df['AcceptedDate']).year

# %% [markdown]
# i created a new column called year based on the AcceptedDate column, but used only the year information

# %%
df.sample()
# Out:
#         ECRef RegulatedEntityName RegulatedEntityType AcceptedDate  \
# 215  C0393884        Labour Party     Political Party   2017-11-06
#
#     AccountingUnitName           DonorName  AccountingUnitsAsCentralParty  \
# 215      Central Party  Mr William Haughey                          False
#
#      IsSponsorship DonorStatus  RegulatedDoneeType  ...  IsBequest  \
# 215          False  Individual                 NaN  ...      False
#
#      IsAggregation RegulatedEntityId AccountingUnitId  DonorId  \
# 215          False                53              NaN    37529
#
#      CampaigningName   RegisterName IsIrishSource    Value  Year
# 215              NaN  Great Britain         False  30000.0  2017
#
# [1 rows x 30 columns]

# %%
df.sample(10)
# Out:
#          ECRef              RegulatedEntityName RegulatedEntityType  \
# 11    C0364240                Liberal Democrats     Political Party
# 217  NC0376434  Conservative and Unionist Party     Political Party
# 112   C0376425  Conservative and Unionist Party     Political Party
# 74    C0364165                Liberal Democrats     Political Party
# 194   C0376312  Conservative and Unionist Party     Political Party
# 94    C0364260                Liberal Democrats     Political Party
# 231  NC0376442  Conservative and Unionist Party     Political Party
# 202   C0376292  Conservative and Unionist Party     Political Party
# 101   C0364234                Liberal Democrats     Political Party
# 56    C0364229                Liberal Democrats     Political Party
#
#     AcceptedDate                AccountingUnitName               DonorName  \
# 11    2017-12-31                           Walsall         Cllr Ian Shires
# ...

# %%
df['Month'] = pd.DatetimeIndex(df['AcceptedDate']).month
df.tail(10)
# Out:
#          ECRef              RegulatedEntityName RegulatedEntityType  \
# 290  NC0364001     UK Independence Party (UKIP)     Political Party
# 291   C0376428  Conservative and Unionist Party     Political Party
# 292   C0363992     UK Independence Party (UKIP)     Political Party
# 293   C0364019     UK Independence Party (UKIP)     Political Party
# 294   C0363993     UK Independence Party (UKIP)     Political Party
# 295   C0363988     UK Independence Party (UKIP)     Political Party
# 296   C0364018     UK Independence Party (UKIP)     Political Party
# 297   C0364007     UK Independence Party (UKIP)     Political Party
# 298   C0363987     UK Independence Party (UKIP)     Political Party
# 299   C0393892                     Labour Party     Political Party
#
#     AcceptedDate        AccountingUnitName                  DonorName  \
# 290   2017-03-31   Harwich and North Essex        Mr Duncan Greenland
# 291   2017-03-27                    Havant             Mr Jeremy Hand
# ...

# %% [markdown]
# i created a new column called month based on the AcceptedDate column, but used only the month information

# %%
df.columns
# Out:
# Index(['ECRef', 'RegulatedEntityName', 'RegulatedEntityType', 'AcceptedDate',
#        'AccountingUnitName', 'DonorName', 'AccountingUnitsAsCentralParty',
#        'IsSponsorship', 'DonorStatus', 'RegulatedDoneeType',
#        'CompanyRegistrationNumber', 'Postcode', 'DonationType',
#        'NatureOfDonation', 'PurposeOfVisit', 'DonationAction', 'ReceivedDate',
#        'ReportedDate', 'IsReportedPrePoll', 'ReportingPeriodName', 'IsBequest',
#        'IsAggregation', 'RegulatedEntityId', 'AccountingUnitId', 'DonorId',
#        'CampaigningName', 'RegisterName', 'IsIrishSource', 'Value', 'Year',
#        'Month'],
#       dtype='object')

# %%
df.shape
# Out:
# (300, 31)

# %%
dfMini = df[['RegulatedEntityName', 'AcceptedDate', 'DonorName', 'DonorStatus' ,'Year', 'Month', 'Value', 'RegulatedEntityType', 'DonorId','CampaigningName']]

# %%
dfMini.sample()
# Out:
#    RegulatedEntityName AcceptedDate        DonorName DonorStatus  Year  Month  \
# 98   Liberal Democrats   2017-12-31  Mr Tom  Gosling  Individual  2017     12
#
#       Value RegulatedEntityType  DonorId  CampaigningName
# 98  10000.0     Political Party    78783              NaN

# %%
dfMini.to_csv('results_clean.csv', encoding ='utf8')

# %% [markdown]
# i saved the dfMini to csv named results_clean.csv with the utf8 encoding format

# %%
ls
# Out:
# '2 Clean data.ipynb'              'Clean data v2.ipynb'  'teste notebook.ipynb'
# 'Clean data - Complete v2.ipynb'   results_clean.csv     'Test Notebook.ipynb'
#  cleandata.ipynb                   results.csv
