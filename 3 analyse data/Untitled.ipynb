# %%
import pandas as pd

# %% [markdown]
# i import the pandas libraries and call it "pd" so i can use only pd to use the library

# %%
df = pd.read_csv('results_clean.csv')

# %% [markdown]
# i imported the document results_clean.csv using the pandas library e put it in a data frame called df

# %%
df.head(10)
# Out:
#    Unnamed: 0               RegulatedEntityName AcceptedDate  \
# 0           0  Plaid Cymru - The Party of Wales   2018-12-19
# 1           1                 Liberal Democrats   2017-12-31
# 2           2                 Liberal Democrats   2017-12-31
# 3           3                 Liberal Democrats   2017-12-31
# 4           4                 Liberal Democrats   2017-12-31
# 5           5                 Liberal Democrats   2017-12-31
# 6           6                 Liberal Democrats   2017-12-31
# 7           7                 Liberal Democrats   2017-12-31
# 8           8                 Liberal Democrats   2017-12-31
# 9           9                 Liberal Democrats   2017-12-31
#
#                     DonorName DonorStatus  Year  Month    Value  \
# 0         Mr Alun Ffred Jones  Individual  2018     12  20000.0
# 1            Ms Kirsten Bayes  Individual  2017     12   1800.0
# 2              Mr Steve  Webb  Individual  2017     12   3000.0
# ...

# %% [markdown]
# this command show the first 10 rows

# %%
df = df.drop('Unnamed: 0', 1)

# %% [markdown]
# this command exclude the collum named 'unnamed: 0', the 1 means that is in the vertical axis (collum). 0 means horizontal axis (row)

# %%
df.sample(9)
# Out:
#                   RegulatedEntityName AcceptedDate  \
# 178                 Liberal Democrats   2017-11-29
# 88                  Liberal Democrats   2017-12-31
# 139                      Labour Party   2017-12-13
# 90                  Liberal Democrats   2017-12-31
# 105   Conservative and Unionist Party   2017-12-28
# 200  Plaid Cymru - The Party of Wales   2017-11-17
# 17                  Liberal Democrats   2017-12-31
# 62                  Liberal Democrats   2017-12-31
# 287   Conservative and Unionist Party   2017-04-20
#
#                             DonorName DonorStatus  Year  Month     Value  \
# 178                   Lord Paul Tyler  Individual  2017     11   2400.00
# 88   Lord Nigel D Jones of Cheltenham  Individual  2017     12   1850.00
# 139               Mr Stephen Kinsella  Individual  2017     12   4957.00
# 90                  Mrs Marlene Heron  Individual  2017     12   1720.00
# 105                      Mike Penning  Individual  2017     12   1510.00
# ...

# %% [markdown]
# this command give me random sample of 9 rows

# %%
df.describe()
# Out:
#               Year       Month          Value       DonorId  CampaigningName
# count   300.000000  300.000000     300.000000    300.000000              0.0
# mean   2017.003333   10.623333   10488.400400  65556.336667              NaN
# std       0.057735    2.544873   32153.305738  19466.692599              NaN
# min    2017.000000    1.000000     600.000000  19152.000000              NaN
# 25%    2017.000000   10.000000    1800.000000  47058.000000              NaN
# 50%    2017.000000   12.000000    2500.000000  76334.000000              NaN
# 75%    2017.000000   12.000000    8124.000000  83335.500000              NaN
# max    2018.000000   12.000000  400000.000000  84031.000000              NaN

# %% [markdown]
# this command give a description of my dataframe. count: number os values in that collum; unique: number of unique value in that column; top: first value in that column; freq: the mons common value's frequency; mean: average; std: standar deviation; min: minimum value, lowest value in the column; 25%: first percentile; 50%: second percetile, this is the same as the median; 75%: thirth percentile; max: maximum value, highest value in that column.

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (300, 10)

# %% [markdown]
# this command show how many rows and columns my dataframe have

# %%
df.sample(1)
# Out:
#     RegulatedEntityName AcceptedDate           DonorName DonorStatus  Year  \
# 265   Liberal Democrats   2017-08-06  Mr Mark  Petterson  Individual  2017
#
#      Month   Value RegulatedEntityType  DonorId  CampaigningName
# 265      8  4000.0     Political Party    55995              NaN

# %% [markdown]
# i want to know the name of my columns with the smple command

# %%
df[df['Value']==11750.00]
# Out:
#                  RegulatedEntityName AcceptedDate          DonorName  \
# 192  Conservative and Unionist Party   2017-11-21  Ms Rania K Majeed
#
#     DonorStatus  Year  Month    Value RegulatedEntityType  DonorId  \
# 192  Individual  2017     11  11750.0     Political Party    83842
#
#      CampaigningName
# 192              NaN

# %% [markdown]
# this command filter and show me every Value in the column Value over 10000

# %%
df[df['Value']<601]
# Out:
#                  RegulatedEntityName AcceptedDate               DonorName  \
# 151                      Green Party   2017-12-07     Ms Jean Lambert MEP
# 216                      Green Party   2017-11-05     Ms Jean Lambert MEP
# 237                      Green Party   2017-10-22     Ms Jean Lambert MEP
# 241  Conservative and Unionist Party   2017-10-17  Scirard Lancelyn Green
# 242  Conservative and Unionist Party   2017-10-17  Scirard Lancelyn Green
#
#     DonorStatus  Year  Month  Value RegulatedEntityType  DonorId  \
# 151  Individual  2017     12  600.0     Political Party    34382
# 216  Individual  2017     11  600.0     Political Party    34382
# 237  Individual  2017     10  600.0     Political Party    34382
# 241  Individual  2017     10  600.0     Political Party    76334
# 242  Individual  2017     10  600.0     Political Party    76334
#
#      CampaigningName
# 151              NaN
# 216              NaN
# 237              NaN
# 241              NaN
# ...

# %%
df.sort_values(by='Value')
# Out:
#                  RegulatedEntityName AcceptedDate               DonorName  \
# 216                      Green Party   2017-11-05     Ms Jean Lambert MEP
# 151                      Green Party   2017-12-07     Ms Jean Lambert MEP
# 242  Conservative and Unionist Party   2017-10-17  Scirard Lancelyn Green
# 241  Conservative and Unionist Party   2017-10-17  Scirard Lancelyn Green
# 237                      Green Party   2017-10-22     Ms Jean Lambert MEP
# ..                               ...          ...                     ...
# 238  Conservative and Unionist Party   2017-10-19         Mr Ian R Taylor
# 128  Conservative and Unionist Party   2017-12-14       Lord Stanley Fink
# 257    Scottish National Party (SNP)   2017-10-06           Mr Ian McNish
# 137  Conservative and Unionist Party   2017-12-14        Mr Michael Davis
# 229  Conservative and Unionist Party   2017-10-30        Mr Byron S Huson
#
#     DonorStatus  Year  Month     Value RegulatedEntityType  DonorId  \
# ...

# %% [markdown]
# this command sort the dataframe by value, using the column Values, starting from the lowest to the highest

# %%
df.sort_values(by='Value', ascending=False).head(10)
# Out:
#                   RegulatedEntityName AcceptedDate             DonorName  \
# 229   Conservative and Unionist Party   2017-10-30      Mr Byron S Huson
# 137   Conservative and Unionist Party   2017-12-14      Mr Michael Davis
# 257     Scottish National Party (SNP)   2017-10-06         Mr Ian McNish
# 128   Conservative and Unionist Party   2017-12-14     Lord Stanley Fink
# 248   Conservative and Unionist Party   2017-10-11     Ms Lesley Jackson
# 238   Conservative and Unionist Party   2017-10-19       Mr Ian R Taylor
# 200  Plaid Cymru - The Party of Wales   2017-11-17    Ms Jane Mactaggart
# 202   Conservative and Unionist Party   2017-11-16      Mrs Mary Erbrich
# 254   Conservative and Unionist Party   2017-10-09  Mr Michael A Dangoor
# 219   Conservative and Unionist Party   2017-11-01     Mr Oluwole Kolade
#
#     DonorStatus  Year  Month      Value RegulatedEntityType  DonorId  \
# 229  Individual  2017     10  400000.00     Political Party    83882
# ...

# %% [markdown]
# the same above, but sorting from the highest to the lowests, and showing me only the firts 10 rows

# %%
df['Value'].sum()
# Out:
# 3146520.12

# %% [markdown]
# this command sum all the numbers on the Value column

# %%
df['RegulatedEntityName'].count()
# Out:
# 300

# %%
df['RegulatedEntityName'].value_counts()
# Out:
# Liberal Democrats                   124
# Conservative and Unionist Party     117
# UK Independence Party (UKIP)         20
# Labour Party                         18
# Scottish Green Party                  6
# Green Party                           5
# Plaid Cymru - The Party of Wales      3
# Scottish National Party (SNP)         3
# Renew                                 2
# Women's Equality Party                1
# British National Party                1
# Name: RegulatedEntityName, dtype: int64

# %% [markdown]
# this command show how many times the information in the Regulated Entity Name column is repetitive, in other words, how many  wich party received a donation

# %%
df['DonorName'].count()
# Out:
# 300

# %%
df['DonorName'].value_counts()
# Out:
# Ms Jane Mactaggart                   9
# Mr Duncan Greenland                  8
# Lord Charles Falconer of Thoroton    6
# Mr Malcolm Bluemel                   5
# Mr Mark  Petterson                   4
#                                     ..
# Mr Simon D Hume-Kendall              1
# Hon George T Farmer                  1
# Mr Iain Aitken                       1
# Lord Nigel D Jones of Cheltenham     1
# Mr Peter Wilson                      1
# Name: DonorName, Length: 247, dtype: int64

# %% [markdown]
# this command show how many times the information in the Donor Name column is repetitive, in other words, how many times a  person donate

# %%
df.groupby('DonorName')['Value'].sum()
# Out:
# DonorName
# Baroness Barbara Janke         1600.00
# Baroness Emma Nicholson        2499.99
# Baroness Kathryn Parminter     2400.00
# Baroness Shirley Williams      1700.00
# Christopher Williams           1506.37
#                                 ...
# Roger Michael Isherwood        2800.00
# Scirard Lancelyn Green         2400.00
# Sir Michael Hintze             2500.00
# Stella Creasy                  1947.05
# William  Goodhart             20000.00
# Name: Value, Length: 247, dtype: float64

# %% [markdown]
# this command group the Donor Name by the column value and sum all what the person donated
